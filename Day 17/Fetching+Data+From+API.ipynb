# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=40dcb004d006fe605729a6bc8399592c&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])

# %%
df = df.head()[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]

# %%
df
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     134.064
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     124.789
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     153.549
# 3  The true story of how businessman Oskar Schind...   1993-12-15      72.259
# 4  The defense and the prosecution have rested an...   1957-04-10      77.730
#
#    vote_average  vote_count
# 0         8.706       26246
# 1         8.694       19900
# 2         8.576       12015
# 3         8.567       15425
# 4         8.500        8287

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1, 429):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=40dcb004d006fe605729a6bc8399592c&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count' ]]
    df = df.append(temp_df,ignore_index=1)
# Out:
# C:\Users\SUNIL\AppData\Local\Temp\ipykernel_28968\1970871523.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=1)
# C:\Users\SUNIL\AppData\Local\Temp\ipykernel_28968\1970871523.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=1)
# C:\Users\SUNIL\AppData\Local\Temp\ipykernel_28968\1970871523.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=1)
# C:\Users\SUNIL\AppData\Local\Temp\ipykernel_28968\1970871523.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=1)
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
